# %%
import pandas as pd
import numpy as np
import gc

gc.enable()

DATA = '~/Data/Molecular'

data = pd.concat([
    pd.read_pickle(f"{DATA}/basic.gz"),
    pd.read_pickle(f"{DATA}/angle_feature.gz"),
    pd.read_pickle(f"{DATA}/criskiev_distance_feature.gz"),
    pd.read_pickle(f"{DATA}/qm9.gz")
], axis = 1)
data = data.iloc[:4658147, :]
data['random_feature'] = np.require(np.random.rand(data.shape[0]), 'float32')
y = pd.read_csv(f"{DATA}/train.csv", dtype={
    'molecule_name': 'category',
    'atom_index_0': 'int8',
    'atom_index_1': 'int8',
    'type': 'category',
    'scalar_coupling_constant': 'float32'
}, usecols=['scalar_coupling_constant'])

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

folds = KFold(n_splits=5, random_state=49, shuffle=True)
drop_feature_loss = dict()
for bond in pd.unique(data['type']):
    X = data[data['type'] == bond]
    yt = y[data['type'] == bond]
    print(f"For bond type {bond}:")
    for i, feature_name in enumerate(data.columns[13:]):
        feature_index = [j for j,itm in enumerate(data.columns) if j > 13 and j != 13+i]
        loss_ = []
        for it, iv in folds.split(X, y = yt['scalar_coupling_constant']):
            lr = LinearRegression()
            lr.fit(X.iloc[it, feature_index], yt.iloc[it, 0])
            yv_ = lr.predict(X.iloc[iv, feature_index])
            loss_.append(mean_absolute_error(yt.iloc[iv, 0].values, yv_))
        drop_feature_loss[feature_name] = np.log(np.mean(loss_))
        print(f"{feature_name},{drop_feature_loss[feature_name]}")
# Out:
# For bond type 1JHC:
# dist_x,1.151504397392273
# dist_y,1.096468210220337
# dist_z,1.1936919689178467
# dist,1.1554853916168213
# dist_x_molecule_mean,1.1426970958709717
# dist_x_molecule_std,1.1297916173934937
# dist_x_molecule_min,1.1107902526855469
# dist_x_molecule_max,1.1262530088424683
# dist_x_molecule_median,1.1004325151443481
# dist_x_molecule_skew,1.1268310546875
# dist_y_molecule_mean,1.2002891302108765
# dist_y_molecule_std,1.1287105083465576
# dist_y_molecule_min,1.1299512386322021
# dist_y_molecule_max,1.1140023469924927
# dist_y_molecule_median,1.1365597248077393
# dist_y_molecule_skew,1.1075795888900757
# dist_z_molecule_mean,1.1222314834594727
# dist_z_molecule_std,1.1167654991149902
# dist_z_molecule_min,1.1275501251220703
# dist_z_molecule_max,1.1278759241104126
# dist_z_molecule_median,1.1079131364822388
# dist_z_molecule_skew,1.1227000951766968
# dist_molecule_mean,1.1192080974578857
# dist_molecule_std,1.122534990310669
# dist_molecule_min,1.142053246498108
# dist_molecule_max,1.1307653188705444
# dist_molecule_median,1.1194233894348145
# dist_molecule_skew,1.161778450012207
# dist_x_molecule_type_mean,1.1178756952285767
# dist_x_molecule_type_std,1.1240403652191162
# dist_x_molecule_type_min,1.118992567062378
# dist_x_molecule_type_max,1.113027811050415
# dist_x_molecule_type_median,1.1366475820541382
# dist_x_molecule_type_skew,1.1189751625061035
# dist_y_molecule_type_mean,1.1745576858520508
# dist_y_molecule_type_std,1.1091740131378174
# dist_y_molecule_type_min,1.12281334400177
# dist_y_molecule_type_max,1.1284576654434204
# dist_y_molecule_type_median,1.1314319372177124
# dist_y_molecule_type_skew,1.1257864236831665
# dist_z_molecule_type_mean,1.1684061288833618
# dist_z_molecule_type_std,1.1297688484191895
# dist_z_molecule_type_min,1.109534502029419
# dist_z_molecule_type_max,1.1059134006500244
# dist_z_molecule_type_median,1.120545744895935
# dist_z_molecule_type_skew,1.1391451358795166
# dist_molecule_type_mean,1.1132428646087646
# dist_molecule_type_std,1.1071043014526367
# dist_molecule_type_min,1.1286449432373047
# dist_molecule_type_max,1.1171495914459229
# dist_molecule_type_median,1.1171379089355469
# dist_molecule_type_skew,1.1274735927581787
# C,1.1166963577270508
# F,1.2183666229248047
# H,1.1535539627075195
# N,1.1704506874084473
# O,1.1338855028152466
# 1JHC,1.1357231140136719
# 1JHN,1.174533724784851
# 2JHC,1.1240391731262207
# 2JHH,1.1600561141967773
# 2JHN,1.149502158164978
# 3JHC,1.1729767322540283
# 3JHH,1.1151803731918335
# 3JHN,1.155324101448059
# neighbour_count_molecule_atom_0,1.1328834295272827
# neighbour_mean_dist_molecule_atom_0,1.159736156463623
# neighbour_std_dist_molecule_atom_0,1.1340343952178955
# neighbour_min_dist_molecule_atom_0,1.1464661359786987
# neighbour_max_dist_molecule_atom_0,1.136125922203064
# neighbour_median_dist_molecule_atom_0,1.1384050846099854
# neighbour_skew_dist_molecule_atom_0,1.1268516778945923
# neighbour_mean_dist_x_molecule_atom_0,1.1485501527786255
# neighbour_std_dist_x_molecule_atom_0,1.1150420904159546
# neighbour_min_dist_x_molecule_atom_0,1.1087841987609863
# neighbour_max_dist_x_molecule_atom_0,1.1557453870773315
# neighbour_median_dist_x_molecule_atom_0,1.1310944557189941
# neighbour_skew_dist_x_molecule_atom_0,1.1118807792663574
# neighbour_mean_dist_y_molecule_atom_0,1.1173818111419678
# neighbour_std_dist_y_molecule_atom_0,1.120566487312317
# neighbour_min_dist_y_molecule_atom_0,1.1173863410949707
# neighbour_max_dist_y_molecule_atom_0,1.170712947845459
# neighbour_median_dist_y_molecule_atom_0,1.1169027090072632
# neighbour_skew_dist_y_molecule_atom_0,1.1063551902770996
# neighbour_mean_dist_z_molecule_atom_0,1.1127986907958984
# neighbour_std_dist_z_molecule_atom_0,1.1143898963928223
# neighbour_min_dist_z_molecule_atom_0,1.116565227508545
# neighbour_max_dist_z_molecule_atom_0,1.1173821687698364
# neighbour_median_dist_z_molecule_atom_0,1.1119517087936401
# neighbour_skew_dist_z_molecule_atom_0,1.1087191104888916
# neighbour_1JHC_0,1.1204535961151123
# neighbour_1JHN_0,1.143236756324768
# neighbour_2JHC_0,1.1242320537567139
# neighbour_2JHH_0,1.1098452806472778
# neighbour_2JHN_0,1.1336238384246826
# neighbour_3JHC_0,1.1092029809951782
# neighbour_3JHH_0,1.1229262351989746
# neighbour_3JHN_0,1.1247210502624512
# neighbour_C_0,1.1337147951126099
# neighbour_H_0,1.1339977979660034
# neighbour_N_0,1.1614935398101807
# neighbour_count_molecule_atom_1,1.1438008546829224
# neighbour_mean_dist_molecule_atom_1,1.1185321807861328
# neighbour_std_dist_molecule_atom_1,1.1349276304244995
# neighbour_min_dist_molecule_atom_1,1.2295469045639038
# neighbour_max_dist_molecule_atom_1,1.1273276805877686
# neighbour_median_dist_molecule_atom_1,1.1160660982131958
# neighbour_skew_dist_molecule_atom_1,1.1185435056686401
# neighbour_mean_dist_x_molecule_atom_1,1.105238437652588
# neighbour_std_dist_x_molecule_atom_1,1.1136486530303955
# neighbour_min_dist_x_molecule_atom_1,1.103352427482605
# neighbour_max_dist_x_molecule_atom_1,1.1301021575927734
# neighbour_median_dist_x_molecule_atom_1,1.148133397102356
# neighbour_skew_dist_x_molecule_atom_1,1.1321454048156738
# neighbour_mean_dist_y_molecule_atom_1,1.1151204109191895
# neighbour_std_dist_y_molecule_atom_1,1.1307704448699951
# neighbour_min_dist_y_molecule_atom_1,1.1457167863845825
# neighbour_max_dist_y_molecule_atom_1,1.1085638999938965
# neighbour_median_dist_y_molecule_atom_1,1.1071648597717285
# neighbour_skew_dist_y_molecule_atom_1,1.1323989629745483
# neighbour_mean_dist_z_molecule_atom_1,1.103474497795105
# neighbour_std_dist_z_molecule_atom_1,1.112022876739502
# neighbour_min_dist_z_molecule_atom_1,1.1173806190490723
# neighbour_max_dist_z_molecule_atom_1,1.1227812767028809
# neighbour_median_dist_z_molecule_atom_1,1.1071462631225586
# neighbour_skew_dist_z_molecule_atom_1,1.1242300271987915
# neighbour_1JHC_1,1.142707109451294
# neighbour_1JHN_1,1.1358004808425903
# neighbour_2JHC_1,1.1521031856536865
# neighbour_2JHH_1,1.1272636651992798
# neighbour_2JHN_1,1.1272636651992798
# neighbour_3JHC_1,1.151409387588501
# neighbour_3JHH_1,1.1321825981140137
# neighbour_3JHN_1,1.1321825981140137
# neighbour_C_1,1.1321825981140137
# neighbour_H_1,1.1321825981140137
# neighbour_N_1,1.1321825981140137
# dist_0_n,1.139799952507019
# dist_1_n,1.2143495082855225
# dist_0_f,1.15252685546875
# dist_1_f,1.138410210609436
# dist_0_c,1.1428724527359009
# dist_1_c,1.1431618928909302
# cos_a0n0_a1n1,1.1303213834762573
# cos_a0f0_a1f1,1.1281713247299194
# cos_a0c_a1c,1.1188699007034302
# cos_a0n0_a0a1,1.1359667778015137
# cos_a1n1_a0a1,1.1444662809371948
# cos_a0f0_a0a1,1.1420490741729736
# cos_a1f1_a0a1,1.128978967666626
# cos_a0_n_a1_molecule_atom_mean_0,1.1226201057434082
# cos_a0_n_a1_molecule_atom_std_0,1.1703687906265259
# cos_a0_n_a1_molecule_atom_min_0,1.1167279481887817
# cos_a0_n_a1_molecule_atom_max_0,1.1596747636795044
# cos_a0_n_a1_molecule_atom_median_0,1.1309863328933716
# cos_a0_n_a1_molecule_atom_skew_0,1.137189269065857
# cos_a0_f_a1_molecule_atom_mean_0,1.1517082452774048
# cos_a0_f_a1_molecule_atom_std_0,1.171668529510498
# cos_a0_f_a1_molecule_atom_min_0,1.1570168733596802
# cos_a0_f_a1_molecule_atom_max_0,1.155993103981018
# cos_a0_f_a1_molecule_atom_median_0,1.1411490440368652
# cos_a0_f_a1_molecule_atom_skew_0,1.1278780698776245
# cos_a0_n_a1_molecule_atom_mean_1,1.106482982635498
# cos_a0_n_a1_molecule_atom_std_1,1.1088037490844727
# cos_a0_n_a1_molecule_atom_min_1,1.120782494544983
# cos_a0_n_a1_molecule_atom_max_1,1.1655997037887573
# cos_a0_n_a1_molecule_atom_median_1,1.1234045028686523
# cos_a0_n_a1_molecule_atom_skew_1,1.1331758499145508
# cos_a0_f_a1_molecule_atom_mean_1,1.1198790073394775
# cos_a0_f_a1_molecule_atom_std_1,1.1019017696380615
# cos_a0_f_a1_molecule_atom_min_1,1.100909948348999
# cos_a0_f_a1_molecule_atom_max_1,1.1379015445709229
# cos_a0_f_a1_molecule_atom_median_1,1.119757056236267
# cos_a0_f_a1_molecule_atom_skew_1,1.1255202293395996
# dist_n_molecule_mean,1.1085349321365356
# dist_n_molecule_std,1.12398362159729
# dist_n_molecule_min,1.1333491802215576
# dist_n_molecule_max,1.1417936086654663
# dist_n_molecule_median,1.1169624328613281
# dist_n_molecule_skew,1.1084262132644653
# dist_f_molecule_mean,1.1351547241210938
# dist_f_molecule_std,1.1203086376190186
# dist_f_molecule_min,1.139749526977539
# dist_f_molecule_max,1.127586007118225
# dist_f_molecule_median,1.1568306684494019
# dist_f_molecule_skew,1.1349331140518188
# dist_n_molecule_type_mean_0,1.1205081939697266
# dist_n_molecule_type_std_0,1.1125824451446533
# dist_n_molecule_type_min_0,1.1311453580856323
# dist_n_molecule_type_max_0,1.1079304218292236
# dist_n_molecule_type_median_0,1.1163333654403687
# dist_n_molecule_type_skew_0,1.1133430004119873
# dist_f_molecule_type_mean_0,1.107174277305603
# dist_f_molecule_type_std_0,1.1234931945800781
# dist_f_molecule_type_min_0,1.11277174949646
# dist_f_molecule_type_max_0,1.1237924098968506
# dist_f_molecule_type_median_0,1.1298761367797852
# dist_f_molecule_type_skew_0,1.1057480573654175
# dist_n_molecule_type_mean_1,1.141994595527649
# dist_n_molecule_type_std_1,1.118597149848938
# dist_n_molecule_type_min_1,1.1273425817489624
# dist_n_molecule_type_max_1,1.1304187774658203
# dist_n_molecule_type_median_1,1.1124695539474487
# dist_n_molecule_type_skew_1,1.1388742923736572
# dist_f_molecule_type_mean_1,1.1290061473846436
# dist_f_molecule_type_std_1,1.1349605321884155
# dist_f_molecule_type_min_1,1.14154052734375
# dist_f_molecule_type_max_1,1.156298041343689
# dist_f_molecule_type_median_1,1.1352907419204712
# dist_f_molecule_type_skew_1,1.1252777576446533
# atom_2,1.1492551565170288
# atom_3,1.1529709100723267
# atom_4,1.1381772756576538
# atom_5,1.1248098611831665
# atom_6,1.1277549266815186
# atom_7,1.1223028898239136
# atom_8,1.1183584928512573
# atom_9,1.1430467367172241
# d_1_0,1.1457595825195312
# d_2_0,1.1930376291275024
# d_2_1,1.1368393898010254
# d_3_0,1.1206324100494385
# d_3_1,1.1644140481948853
# d_3_2,1.1647562980651855
# d_4_0,1.1424496173858643
# d_4_1,1.153908371925354
# d_4_2,1.147385835647583
# d_4_3,1.1436868906021118
# d_5_0,1.12091064453125
# d_5_1,1.1159662008285522
# d_5_2,1.129586935043335
# d_5_3,1.1291768550872803
# d_6_0,1.1122099161148071
# d_6_1,1.112015724182129
# d_6_2,1.1361247301101685
# d_6_3,1.1190686225891113
# d_7_0,1.1138389110565186
# d_7_1,1.1061513423919678
# d_7_2,1.109951376914978
# d_7_3,1.1267558336257935
# d_8_0,1.129528284072876
# d_8_1,1.1133193969726562
# d_8_2,1.1228604316711426
# d_8_3,1.1266915798187256
# d_9_0,1.1225688457489014
# d_9_1,1.1211034059524536
# d_9_2,1.1137499809265137
# d_9_3,1.1334478855133057
# rc_A,1.0897759199142456
# rc_B,1.135884165763855
# rc_C,1.1173126697540283
# mu,1.107468605041504
# alpha,1.1147198677062988
# homo,1.139954924583435
# lumo,1.16464102268219
# gap,1.1305495500564575
# zpve,1.1032443046569824
# Cv,1.1014134883880615
# freqs_min,1.1241618394851685
# freqs_max,1.1241174936294556
# freqs_mean,1.1254003047943115
# mulliken_min,1.1524016857147217
# mulliken_max,1.117987871170044
# mulliken_atom_0,1.1885266304016113
# mulliken_atom_1,1.113342523574829
# random_feature,1.145633339881897
# For bond type 2JHH:
# dist_x,-0.30392682552337646
# dist_y,-0.2992321848869324
# dist_z,-0.32017600536346436
# dist,-0.34394288063049316
# dist_x_molecule_mean,-0.28833141922950745
# dist_x_molecule_std,-0.26261982321739197
# dist_x_molecule_min,-0.28850096464157104
# dist_x_molecule_max,-0.20628240704536438
# dist_x_molecule_median,-0.2928301990032196
# dist_x_molecule_skew,-0.25226789712905884
# dist_y_molecule_mean,-0.15915654599666595
# dist_y_molecule_std,-0.07505055516958237
# dist_y_molecule_min,-0.24112474918365479
# dist_y_molecule_max,-0.2267725169658661
# dist_y_molecule_median,-0.24329055845737457
# dist_y_molecule_skew,-0.3034629821777344
# dist_z_molecule_mean,-0.2840517461299896
# dist_z_molecule_std,-0.30460307002067566
# dist_z_molecule_min,-0.2936863601207733
# dist_z_molecule_max,-0.3251890540122986
# dist_z_molecule_median,-0.34703370928764343
# dist_z_molecule_skew,-0.29877379536628723
# dist_molecule_mean,-0.26612964272499084
# dist_molecule_std,-0.18135695159435272
# dist_molecule_min,-0.273796945810318
# dist_molecule_max,-0.34321826696395874
# dist_molecule_median,-0.22044523060321808
# dist_molecule_skew,-0.32276058197021484
# dist_x_molecule_type_mean,-0.21456629037857056
# dist_x_molecule_type_std,-0.22452016174793243
# dist_x_molecule_type_min,-0.20247435569763184
# dist_x_molecule_type_max,-0.29429394006729126
# dist_x_molecule_type_median,-0.25302398204803467
# dist_x_molecule_type_skew,-0.30029550194740295
# dist_y_molecule_type_mean,-0.21168488264083862
# dist_y_molecule_type_std,-0.3014996647834778
# dist_y_molecule_type_min,-0.2801423668861389
# dist_y_molecule_type_max,-0.3115164339542389
# dist_y_molecule_type_median,-0.3206399083137512
# dist_y_molecule_type_skew,-0.24528157711029053
# dist_z_molecule_type_mean,-0.26149529218673706
# dist_z_molecule_type_std,-0.20500321686267853
# dist_z_molecule_type_min,-0.20885567367076874
# dist_z_molecule_type_max,-0.30269327759742737
# dist_z_molecule_type_median,-0.28746554255485535
# dist_z_molecule_type_skew,-0.27055683732032776
# dist_molecule_type_mean,-0.2274056226015091
# dist_molecule_type_std,-0.31930920481681824
# dist_molecule_type_min,-0.26810941100120544
# dist_molecule_type_max,-0.2711247205734253
# dist_molecule_type_median,-0.2835552990436554
# dist_molecule_type_skew,-0.31868311762809753
# C,-0.25304025411605835
# F,-0.2695643901824951
# H,-0.2930266559123993
# N,-0.29943737387657166
# O,-0.30309921503067017
# 1JHC,-0.21067151427268982
# 1JHN,-0.3069077134132385
# 2JHC,-0.3152376711368561
# 2JHH,-0.3407362401485443
# 2JHN,-0.2781338393688202
# 3JHC,-0.273458331823349
# 3JHH,-0.23151591420173645
# 3JHN,-0.3040349781513214
# neighbour_count_molecule_atom_0,-0.24646084010601044
# neighbour_mean_dist_molecule_atom_0,-0.3419029414653778
# neighbour_std_dist_molecule_atom_0,-0.26445040106773376
# neighbour_min_dist_molecule_atom_0,-0.2510266900062561
# neighbour_max_dist_molecule_atom_0,-0.3143058121204376
# neighbour_median_dist_molecule_atom_0,-0.28921595215797424
# neighbour_skew_dist_molecule_atom_0,-0.29785531759262085
# neighbour_mean_dist_x_molecule_atom_0,-0.3089653551578522
# neighbour_std_dist_x_molecule_atom_0,-0.25817346572875977
# neighbour_min_dist_x_molecule_atom_0,-0.3181972801685333
# neighbour_max_dist_x_molecule_atom_0,-0.27645236253738403
# neighbour_median_dist_x_molecule_atom_0,-0.24940696358680725
# neighbour_skew_dist_x_molecule_atom_0,-0.2582848072052002
# neighbour_mean_dist_y_molecule_atom_0,-0.26148176193237305
# neighbour_std_dist_y_molecule_atom_0,-0.31252047419548035
# neighbour_min_dist_y_molecule_atom_0,-0.28668802976608276
# neighbour_max_dist_y_molecule_atom_0,-0.1675286889076233
# neighbour_median_dist_y_molecule_atom_0,-0.3199203312397003
# neighbour_skew_dist_y_molecule_atom_0,-0.29298198223114014
# neighbour_mean_dist_z_molecule_atom_0,-0.2263655811548233
# neighbour_std_dist_z_molecule_atom_0,-0.308118999004364
# neighbour_min_dist_z_molecule_atom_0,-0.2632997930049896
# neighbour_max_dist_z_molecule_atom_0,-0.22962909936904907
# neighbour_median_dist_z_molecule_atom_0,-0.2959435284137726
# neighbour_skew_dist_z_molecule_atom_0,-0.24590915441513062
# neighbour_1JHC_0,-0.27673324942588806
# neighbour_1JHN_0,-0.24925720691680908
# neighbour_2JHC_0,-0.3099450469017029
# neighbour_2JHH_0,-0.29280975461006165
# neighbour_2JHN_0,-0.26565349102020264
# neighbour_3JHC_0,-0.3223096430301666
# neighbour_3JHH_0,-0.23754000663757324
# neighbour_3JHN_0,-0.27711260318756104
# neighbour_C_0,-0.2988971471786499
# neighbour_H_0,-0.29461318254470825
# neighbour_N_0,-0.2713673710823059
# neighbour_count_molecule_atom_1,-0.1935383826494217
# neighbour_mean_dist_molecule_atom_1,-0.13686445355415344
# neighbour_std_dist_molecule_atom_1,-0.12960690259933472
# neighbour_min_dist_molecule_atom_1,-0.2738257944583893
# neighbour_max_dist_molecule_atom_1,-0.28514382243156433
# neighbour_median_dist_molecule_atom_1,-0.2923226058483124
# neighbour_skew_dist_molecule_atom_1,-0.2504337430000305
# neighbour_mean_dist_x_molecule_atom_1,-0.30109870433807373
# neighbour_std_dist_x_molecule_atom_1,-0.25345364212989807
# neighbour_min_dist_x_molecule_atom_1,-0.26017463207244873
# neighbour_max_dist_x_molecule_atom_1,-0.2265302687883377
# neighbour_median_dist_x_molecule_atom_1,-0.27622753381729126
# neighbour_skew_dist_x_molecule_atom_1,-0.28471624851226807
# neighbour_mean_dist_y_molecule_atom_1,-0.3197179436683655
# neighbour_std_dist_y_molecule_atom_1,-0.2688778042793274
# neighbour_min_dist_y_molecule_atom_1,-0.2710382640361786
# neighbour_max_dist_y_molecule_atom_1,-0.258101224899292
# neighbour_median_dist_y_molecule_atom_1,-0.2966964840888977
# neighbour_skew_dist_y_molecule_atom_1,-0.24084624648094177
# neighbour_mean_dist_z_molecule_atom_1,-0.25965234637260437
# neighbour_std_dist_z_molecule_atom_1,-0.3009246587753296
# neighbour_min_dist_z_molecule_atom_1,-0.2535816729068756
# neighbour_max_dist_z_molecule_atom_1,-0.30709683895111084
# neighbour_median_dist_z_molecule_atom_1,-0.2213737964630127
# neighbour_skew_dist_z_molecule_atom_1,-0.27720022201538086
# neighbour_1JHC_1,-0.2795136868953705
# neighbour_1JHN_1,-0.2960811257362366
# neighbour_2JHC_1,-0.2648429870605469
# neighbour_2JHH_1,-0.3154607117176056
# neighbour_2JHN_1,-0.29324257373809814
# neighbour_3JHC_1,-0.3444240689277649
# neighbour_3JHH_1,-0.2896197438240051
# neighbour_3JHN_1,-0.2707207500934601
# neighbour_C_1,-0.29431289434432983
# neighbour_H_1,-0.2962050437927246
# neighbour_N_1,-0.16888625919818878
# dist_0_n,-0.2758389413356781
# dist_1_n,-0.15080644190311432
# dist_0_f,-0.30723848938941956
# dist_1_f,-0.3093654215335846
# dist_0_c,-0.26125919818878174
# dist_1_c,-0.3244335353374481
# cos_a0n0_a1n1,-0.2932579815387726
# cos_a0f0_a1f1,-0.32379165291786194
# cos_a0c_a1c,-0.2447207272052765
# cos_a0n0_a0a1,-0.325780987739563
# cos_a1n1_a0a1,-0.308448851108551
# cos_a0f0_a0a1,-0.23582002520561218
# cos_a1f1_a0a1,-0.3284968137741089
# cos_a0_n_a1_molecule_atom_mean_0,-0.12616226077079773
# cos_a0_n_a1_molecule_atom_std_0,-0.3004925549030304
# cos_a0_n_a1_molecule_atom_min_0,-0.2764778137207031
# cos_a0_n_a1_molecule_atom_max_0,-0.3283922076225281
# cos_a0_n_a1_molecule_atom_median_0,-0.18638841807842255
# cos_a0_n_a1_molecule_atom_skew_0,-0.318641722202301
# cos_a0_f_a1_molecule_atom_mean_0,-0.29657885432243347
# cos_a0_f_a1_molecule_atom_std_0,-0.29599297046661377
# cos_a0_f_a1_molecule_atom_min_0,-0.2410101443529129
# cos_a0_f_a1_molecule_atom_max_0,-0.2970348000526428
# cos_a0_f_a1_molecule_atom_median_0,-0.29696300625801086
# cos_a0_f_a1_molecule_atom_skew_0,-0.22564738988876343
# cos_a0_n_a1_molecule_atom_mean_1,-0.3156217038631439
# cos_a0_n_a1_molecule_atom_std_1,-0.21888752281665802
# cos_a0_n_a1_molecule_atom_min_1,-0.22207242250442505
# cos_a0_n_a1_molecule_atom_max_1,-0.33370596170425415
# cos_a0_n_a1_molecule_atom_median_1,-0.2815757989883423
# cos_a0_n_a1_molecule_atom_skew_1,-0.3264331817626953
# cos_a0_f_a1_molecule_atom_mean_1,-0.25370174646377563
# cos_a0_f_a1_molecule_atom_std_1,-0.3167623281478882
# cos_a0_f_a1_molecule_atom_min_1,-0.2827497720718384
# cos_a0_f_a1_molecule_atom_max_1,-0.2183208018541336
# cos_a0_f_a1_molecule_atom_median_1,-0.27499425411224365
# cos_a0_f_a1_molecule_atom_skew_1,-0.3133593499660492
# dist_n_molecule_mean,-0.28970351815223694
# dist_n_molecule_std,-0.3157367706298828
# dist_n_molecule_min,-0.20489054918289185
# dist_n_molecule_max,-0.33067914843559265
# dist_n_molecule_median,-0.23777058720588684
# dist_n_molecule_skew,-0.3126114010810852
# dist_f_molecule_mean,-0.19519421458244324
# dist_f_molecule_std,-0.26888489723205566
# dist_f_molecule_min,-0.30518874526023865
# dist_f_molecule_max,-0.2980005443096161
# dist_f_molecule_median,-0.2413681447505951
# dist_f_molecule_skew,-0.18390977382659912
# dist_n_molecule_type_mean_0,-0.2429371178150177
# dist_n_molecule_type_std_0,-0.31409525871276855
# dist_n_molecule_type_min_0,-0.3189614713191986
# dist_n_molecule_type_max_0,-0.275217205286026
# dist_n_molecule_type_median_0,-0.33382487297058105
# dist_n_molecule_type_skew_0,-0.2910284698009491
# dist_f_molecule_type_mean_0,-0.17163170874118805
# dist_f_molecule_type_std_0,-0.2875754237174988
# dist_f_molecule_type_min_0,-0.28612688183784485
# dist_f_molecule_type_max_0,-0.2008974403142929
# dist_f_molecule_type_median_0,-0.24568119645118713
# dist_f_molecule_type_skew_0,-0.24766522645950317
# dist_n_molecule_type_mean_1,-0.2899768650531769
# dist_n_molecule_type_std_1,-0.16041384637355804
# dist_n_molecule_type_min_1,-0.3149298131465912
# dist_n_molecule_type_max_1,-0.32521766424179077
# dist_n_molecule_type_median_1,-0.2935490906238556
# dist_n_molecule_type_skew_1,-0.306776225566864
# dist_f_molecule_type_mean_1,-0.2526591718196869
# dist_f_molecule_type_std_1,-0.24536126852035522
# dist_f_molecule_type_min_1,-0.32939866185188293
# dist_f_molecule_type_max_1,-0.2762739062309265
# dist_f_molecule_type_median_1,-0.3014177978038788
# dist_f_molecule_type_skew_1,-0.3378560543060303
# atom_2,-0.23903267085552216
# atom_3,-0.21983878314495087
# atom_4,-0.25780004262924194
# atom_5,-0.281729519367218
# atom_6,-0.3175395727157593
# atom_7,-0.32056114077568054
# atom_8,-0.2928087115287781
# atom_9,-0.31205612421035767
# d_1_0,-0.2137521356344223
# d_2_0,-0.27335742115974426
# d_2_1,-0.312894344329834
# d_3_0,-0.24740877747535706
# d_3_1,-0.27813076972961426
# d_3_2,-0.3380652964115143
# d_4_0,-0.30469635128974915
# d_4_1,-0.2635325789451599
# d_4_2,-0.21995678544044495
# d_4_3,-0.31840574741363525
# d_5_0,-0.22694113850593567
# d_5_1,-0.2581275403499603
# d_5_2,-0.27959322929382324
# d_5_3,-0.2018224000930786
# d_6_0,-0.24371333420276642
# d_6_1,-0.3099537491798401
# d_6_2,-0.3201064169406891
# d_6_3,-0.30152538418769836
# d_7_0,-0.2844502925872803
# d_7_1,-0.30853211879730225
# d_7_2,-0.27256208658218384
# d_7_3,-0.18386536836624146
# d_8_0,-0.3056420087814331
# d_8_1,-0.28835320472717285
# d_8_2,-0.2230226993560791
# d_8_3,-0.24668088555335999
# d_9_0,-0.33008986711502075
# d_9_1,-0.27009063959121704
# d_9_2,-0.29052767157554626
# d_9_3,-0.324921190738678
# rc_A,-0.2656840682029724
# rc_B,-0.2179356813430786
# rc_C,-0.3106191158294678
# mu,-0.23733875155448914
# alpha,-0.30521827936172485
# homo,-0.2657037377357483
# lumo,-0.22179260849952698
# gap,-0.318872332572937
# zpve,-0.20257703959941864
# Cv,-0.262302041053772
# freqs_min,-0.2985852062702179
# freqs_max,-0.3372117280960083
# freqs_mean,-0.33242499828338623
# mulliken_min,-0.325565367937088
# mulliken_max,-0.32708147168159485
# mulliken_atom_0,-0.2855048179626465
# mulliken_atom_1,-0.14392481744289398
# random_feature,-0.2883681654930115
# For bond type 1JHN:
# dist_x,0.03488019108772278
# dist_y,0.035055506974458694
# dist_z,0.034778762608766556
# dist,0.03490954637527466
# dist_x_molecule_mean,0.03407757729291916
# dist_x_molecule_std,0.03381485119462013
# dist_x_molecule_min,0.034353017807006836
# dist_x_molecule_max,0.03492025285959244
# dist_x_molecule_median,0.03442546725273132
# dist_x_molecule_skew,0.03393412381410599
# dist_y_molecule_mean,0.03428540378808975
# dist_y_molecule_std,0.034123316407203674
# dist_y_molecule_min,0.034385498613119125
# dist_y_molecule_max,0.03480777516961098
# dist_y_molecule_median,0.034478675574064255
# dist_y_molecule_skew,0.034045200794935226
# dist_z_molecule_mean,0.03421398252248764
# dist_z_molecule_std,0.03437570855021477
# dist_z_molecule_min,0.033939655870199203
# dist_z_molecule_max,0.03496468812227249
# dist_z_molecule_median,0.03395313769578934
# dist_z_molecule_skew,0.0344291515648365
# dist_molecule_mean,0.036094918847084045
# dist_molecule_std,0.03517428785562515
# dist_molecule_min,0.03497423976659775
# dist_molecule_max,0.03435221314430237
# dist_molecule_median,0.034808237105607986
# dist_molecule_skew,0.03361015394330025
# dist_x_molecule_type_mean,0.03320109471678734
# dist_x_molecule_type_std,0.03456458821892738
# dist_x_molecule_type_min,0.0342758409678936
# dist_x_molecule_type_max,0.03353038430213928
# dist_x_molecule_type_median,0.034236446022987366
# dist_x_molecule_type_skew,0.03505585342645645
# dist_y_molecule_type_mean,0.034117668867111206
# dist_y_molecule_type_std,0.0341196283698082
# dist_y_molecule_type_min,0.03367885202169418
# dist_y_molecule_type_max,0.03452393785119057
# dist_y_molecule_type_median,0.03418587148189545
# dist_y_molecule_type_skew,0.034866031259298325
# dist_z_molecule_type_mean,0.03419416770339012
# dist_z_molecule_type_std,0.03414244204759598
# dist_z_molecule_type_min,0.03391626104712486
# dist_z_molecule_type_max,0.0345112681388855
# dist_z_molecule_type_median,0.03398874029517174
# dist_z_molecule_type_skew,0.0347994863986969
# dist_molecule_type_mean,0.03344957157969475
# dist_molecule_type_std,0.03525369614362717
# dist_molecule_type_min,0.03470875695347786
# dist_molecule_type_max,0.03404473885893822
# dist_molecule_type_median,0.034038979560136795
# dist_molecule_type_skew,0.036287155002355576
# C,0.03479073569178581
# F,0.035472322255373
# H,0.03474675491452217
# N,0.034919675439596176
# O,0.033847466111183167
# 1JHC,0.03551650419831276
# 1JHN,0.03499196842312813
# 2JHC,0.03471497446298599
# 2JHH,0.034086793661117554
# 2JHN,0.034983448684215546
# 3JHC,0.03479718416929245
# 3JHH,0.03518027067184448
# 3JHN,0.03473075106739998
# neighbour_count_molecule_atom_0,0.034147050231695175
# neighbour_mean_dist_molecule_atom_0,0.03449998050928116
# neighbour_std_dist_molecule_atom_0,0.033514704555273056
# neighbour_min_dist_molecule_atom_0,0.03500796854496002
# neighbour_max_dist_molecule_atom_0,0.03474341332912445
# neighbour_median_dist_molecule_atom_0,0.03433055803179741
# neighbour_skew_dist_molecule_atom_0,0.03364703804254532
# neighbour_mean_dist_x_molecule_atom_0,0.033896442502737045
# neighbour_std_dist_x_molecule_atom_0,0.03379134088754654
# neighbour_min_dist_x_molecule_atom_0,0.034968484193086624
# neighbour_max_dist_x_molecule_atom_0,0.03371826931834221
# neighbour_median_dist_x_molecule_atom_0,0.03436499834060669
# neighbour_skew_dist_x_molecule_atom_0,0.03439275547862053
# neighbour_mean_dist_y_molecule_atom_0,0.03421398252248764
# neighbour_std_dist_y_molecule_atom_0,0.03459429740905762
# neighbour_min_dist_y_molecule_atom_0,0.03388676047325134
# neighbour_max_dist_y_molecule_atom_0,0.03520236909389496
# neighbour_median_dist_y_molecule_atom_0,0.03535196930170059
# neighbour_skew_dist_y_molecule_atom_0,0.03428379073739052
# neighbour_mean_dist_z_molecule_atom_0,0.03411306068301201
# neighbour_std_dist_z_molecule_atom_0,0.035262901335954666
# neighbour_min_dist_z_molecule_atom_0,0.03393469750881195
# neighbour_max_dist_z_molecule_atom_0,0.03479798883199692
# neighbour_median_dist_z_molecule_atom_0,0.03371838480234146
# neighbour_skew_dist_z_molecule_atom_0,0.034716010093688965
# neighbour_1JHC_0,0.03475527465343475
# neighbour_1JHN_0,0.03776400163769722
# neighbour_2JHC_0,0.03493982180953026
# neighbour_2JHH_0,0.0345793291926384
# neighbour_2JHN_0,0.034686651080846786
# neighbour_3JHC_0,0.03416421636939049
# neighbour_3JHH_0,0.034585315734148026
# neighbour_3JHN_0,0.034140367060899734
# neighbour_C_0,0.034260060638189316
# neighbour_H_0,0.03499116376042366
# neighbour_N_0,0.033843085169792175
# neighbour_count_molecule_atom_1,0.03473972901701927
# neighbour_mean_dist_molecule_atom_1,0.03408080339431763
# neighbour_std_dist_molecule_atom_1,0.03374028578400612
# neighbour_min_dist_molecule_atom_1,0.03574071079492569
# neighbour_max_dist_molecule_atom_1,0.03423195332288742
# neighbour_median_dist_molecule_atom_1,0.03377290070056915
# neighbour_skew_dist_molecule_atom_1,0.034868791699409485
# neighbour_mean_dist_x_molecule_atom_1,0.03447522222995758
# neighbour_std_dist_x_molecule_atom_1,0.034273192286491394
# neighbour_min_dist_x_molecule_atom_1,0.034804895520210266
# neighbour_max_dist_x_molecule_atom_1,0.03410902991890907
# neighbour_median_dist_x_molecule_atom_1,0.03504088893532753
# neighbour_skew_dist_x_molecule_atom_1,0.03383743762969971
# neighbour_mean_dist_y_molecule_atom_1,0.034516219049692154
# neighbour_std_dist_y_molecule_atom_1,0.034254416823387146
# neighbour_min_dist_y_molecule_atom_1,0.034397248178720474
# neighbour_max_dist_y_molecule_atom_1,0.03482009470462799
# neighbour_median_dist_y_molecule_atom_1,0.034763794392347336
# neighbour_skew_dist_y_molecule_atom_1,0.034042779356241226
# neighbour_mean_dist_z_molecule_atom_1,0.033981483429670334
# neighbour_std_dist_z_molecule_atom_1,0.0337442010641098
# neighbour_min_dist_z_molecule_atom_1,0.034439634531736374
# neighbour_max_dist_z_molecule_atom_1,0.03393227979540825
# neighbour_median_dist_z_molecule_atom_1,0.034423161298036575
# neighbour_skew_dist_z_molecule_atom_1,0.03524195775389671
# neighbour_1JHC_1,0.03480558842420578
# neighbour_1JHN_1,0.03485290706157684
# neighbour_2JHC_1,0.03474053740501404
# neighbour_2JHH_1,0.03474053740501404
# neighbour_2JHN_1,0.0351208820939064
# neighbour_3JHC_1,0.03478647395968437
# neighbour_3JHH_1,0.03478647395968437
# neighbour_3JHN_1,0.034896884113550186
# neighbour_C_1,0.0349138043820858
# neighbour_H_1,0.03491368889808655
# neighbour_N_1,0.03491368889808655
# dist_0_n,0.03476943448185921
# dist_1_n,0.03566398471593857
# dist_0_f,0.03476828336715698
# dist_1_f,0.034167900681495667
# dist_0_c,0.03702412545681
# dist_1_c,0.038002509623765945
# cos_a0n0_a1n1,0.03407112509012222
# cos_a0f0_a1f1,0.03586722910404205
# cos_a0c_a1c,0.03706846758723259
# cos_a0n0_a0a1,0.034955594688653946
# cos_a1n1_a0a1,0.03482711687684059
# cos_a0f0_a0a1,0.03573093190789223
# cos_a1f1_a0a1,0.03560612350702286
# cos_a0_n_a1_molecule_atom_mean_0,0.03716931864619255
# cos_a0_n_a1_molecule_atom_std_0,0.03783700615167618
# cos_a0_n_a1_molecule_atom_min_0,0.03494592383503914
# cos_a0_n_a1_molecule_atom_max_0,0.03484070301055908
# cos_a0_n_a1_molecule_atom_median_0,0.03292614221572876
# cos_a0_n_a1_molecule_atom_skew_0,0.0349883995950222
# cos_a0_f_a1_molecule_atom_mean_0,0.03352611884474754
# cos_a0_f_a1_molecule_atom_std_0,0.033620528876781464
# cos_a0_f_a1_molecule_atom_min_0,0.03451092168688774
# cos_a0_f_a1_molecule_atom_max_0,0.03486395627260208
# cos_a0_f_a1_molecule_atom_median_0,0.03489561751484871
# cos_a0_f_a1_molecule_atom_skew_0,0.0359768271446228
# cos_a0_n_a1_molecule_atom_mean_1,0.033837784081697464
# cos_a0_n_a1_molecule_atom_std_1,0.03875783085823059
# cos_a0_n_a1_molecule_atom_min_1,0.03854714706540108
# cos_a0_n_a1_molecule_atom_max_1,0.03474709764122963
# cos_a0_n_a1_molecule_atom_median_1,0.03936348855495453
# cos_a0_n_a1_molecule_atom_skew_1,0.03915625438094139
# cos_a0_f_a1_molecule_atom_mean_1,0.03380228951573372
# cos_a0_f_a1_molecule_atom_std_1,0.03723892197012901
# cos_a0_f_a1_molecule_atom_min_1,0.03704848140478134
# cos_a0_f_a1_molecule_atom_max_1,0.03476160764694214
# cos_a0_f_a1_molecule_atom_median_1,0.03516910597681999
# cos_a0_f_a1_molecule_atom_skew_1,0.03790966048836708
# dist_n_molecule_mean,0.03573668375611305
# dist_n_molecule_std,0.034812379628419876
# dist_n_molecule_min,0.034698739647865295
# dist_n_molecule_max,0.03392179310321808
# dist_n_molecule_median,0.03375618904829025
# dist_n_molecule_skew,0.03487972915172577
# dist_f_molecule_mean,0.0344172902405262
# dist_f_molecule_std,0.034351520240306854
# dist_f_molecule_min,0.03420925885438919
# dist_f_molecule_max,0.034297384321689606
# dist_f_molecule_median,0.034112945199012756
# dist_f_molecule_skew,0.03401673957705498
# dist_n_molecule_type_mean_0,0.03569722920656204
# dist_n_molecule_type_std_0,0.03490551561117172
# dist_n_molecule_type_min_0,0.03458024933934212
# dist_n_molecule_type_max_0,0.034852445125579834
# dist_n_molecule_type_median_0,0.03400199115276337
# dist_n_molecule_type_skew_0,0.03420107811689377
# dist_f_molecule_type_mean_0,0.03373555839061737
# dist_f_molecule_type_std_0,0.033866941928863525
# dist_f_molecule_type_min_0,0.03502638638019562
# dist_f_molecule_type_max_0,0.034236907958984375
# dist_f_molecule_type_median_0,0.0339205265045166
# dist_f_molecule_type_skew_0,0.03525231406092644
# dist_n_molecule_type_mean_1,0.034230686724185944
# dist_n_molecule_type_std_1,0.03394564613699913
# dist_n_molecule_type_min_1,0.03461986407637596
# dist_n_molecule_type_max_1,0.0341222807765007
# dist_n_molecule_type_median_1,0.034779567271471024
# dist_n_molecule_type_skew_1,0.03382948786020279
# dist_f_molecule_type_mean_1,0.034091170877218246
# dist_f_molecule_type_std_1,0.034508850425481796
# dist_f_molecule_type_min_1,0.03394230455160141
# dist_f_molecule_type_max_1,0.03375503793358803
# dist_f_molecule_type_median_1,0.03446255251765251
# dist_f_molecule_type_skew_1,0.03397352993488312
# atom_2,0.09776592999696732
# atom_3,0.04361772537231445
# atom_4,0.06414119154214859
# atom_5,0.05205678939819336
# atom_6,0.03668656200170517
# atom_7,0.03512997552752495
# atom_8,0.03517888858914375
# atom_9,0.03494776412844658
# d_1_0,0.03509751707315445
# d_2_0,0.0559830479323864
# d_2_1,0.09719809889793396
# d_3_0,0.05978672206401825
# d_3_1,0.09179733693599701
# d_3_2,0.198888897895813
# d_4_0,0.03528982773423195
# d_4_1,0.03504180908203125
# d_4_2,0.035842958837747574
# d_4_3,0.036646343767642975
# d_5_0,0.035001061856746674
# d_5_1,0.03393227979540825
# d_5_2,0.03588390350341797
# d_5_3,0.041540615260601044
# d_6_0,0.03307054936885834
# d_6_1,0.03697461262345314
# d_6_2,0.03577866777777672
# d_6_3,0.03736536577343941
# d_7_0,0.0360882505774498
# d_7_1,0.03815788775682449
# d_7_2,0.036202654242515564
# d_7_3,0.03410591930150986
# d_8_0,0.037391435354948044
# d_8_1,0.037618089467287064
# d_8_2,0.03917505592107773
# d_8_3,0.034581977874040604
# d_9_0,0.03474007546901703
# d_9_1,0.035610608756542206
# d_9_2,0.0370311364531517
# d_9_3,0.03464289382100105
# rc_A,0.03566030412912369
# rc_B,0.03609032183885574
# rc_C,0.03528200462460518
# mu,0.03454570099711418
# alpha,0.03630244359374046
# homo,0.03465579077601433
# lumo,0.03395567089319229
# gap,0.03413644805550575
# zpve,0.03467801213264465
# Cv,0.03455767780542374
# freqs_min,0.035490959882736206
# freqs_max,0.03472556918859482
# freqs_mean,0.035410076379776
# mulliken_min,0.03440795838832855
# mulliken_max,0.03448167070746422
# mulliken_atom_0,0.1568363904953003
# mulliken_atom_1,0.044098518788814545
# random_feature,0.034973204135894775
# For bond type 2JHN:
# dist_x,-0.3195119798183441
# dist_y,-0.3174229860305786
# dist_z,-0.31944775581359863
# dist,-0.32067981362342834
# dist_x_molecule_mean,-0.32042449712753296
# dist_x_molecule_std,-0.32057493925094604
# dist_x_molecule_min,-0.32057639956474304
# dist_x_molecule_max,-0.32002702355384827
# dist_x_molecule_median,-0.3203795552253723
# dist_x_molecule_skew,-0.2862702012062073
# dist_y_molecule_mean,-0.32009515166282654
# dist_y_molecule_std,-0.32033661007881165
# dist_y_molecule_min,-0.32077181339263916
# dist_y_molecule_max,-0.32035163044929504
# dist_y_molecule_median,-0.3206256031990051
# dist_y_molecule_skew,-0.32085806131362915
# dist_z_molecule_mean,-0.2923183739185333
# dist_z_molecule_std,-0.32056352496147156
# dist_z_molecule_min,-0.3208169937133789
# dist_z_molecule_max,-0.320548415184021
# dist_z_molecule_median,-0.3205786347389221
# dist_z_molecule_skew,-0.3204612731933594
# dist_molecule_mean,-0.31963014602661133
# dist_molecule_std,-0.3211100697517395
# dist_molecule_min,-0.3195952773094177
# dist_molecule_max,-0.28787440061569214
# dist_molecule_median,-0.3203403949737549
# dist_molecule_skew,-0.3203169107437134
# dist_x_molecule_type_mean,-0.32097193598747253
# dist_x_molecule_type_std,-0.2720187306404114
# dist_x_molecule_type_min,-0.29214662313461304
# dist_x_molecule_type_max,-0.3202436566352844
# dist_x_molecule_type_median,-0.3208472430706024
# dist_x_molecule_type_skew,-0.3197632431983948
# dist_y_molecule_type_mean,-0.28983134031295776
# dist_y_molecule_type_std,-0.3022867441177368
# dist_y_molecule_type_min,-0.29195553064346313
# dist_y_molecule_type_max,-0.32059651613235474
# dist_y_molecule_type_median,-0.32087385654449463
# dist_y_molecule_type_skew,-0.3205035626888275
# dist_z_molecule_type_mean,-0.2900813817977905
# dist_z_molecule_type_std,-0.2952232360839844
# dist_z_molecule_type_min,-0.32064491510391235
# dist_z_molecule_type_max,-0.32045552134513855
# dist_z_molecule_type_median,-0.2882693111896515
# dist_z_molecule_type_skew,-0.3200199604034424
# dist_molecule_type_mean,-0.32055923342704773
# dist_molecule_type_std,-0.32113251090049744
# dist_molecule_type_min,-0.3211241364479065
# dist_molecule_type_max,-0.32100045680999756
# dist_molecule_type_median,-0.32113611698150635
# dist_molecule_type_skew,-0.31947940587997437
# C,-0.28472140431404114
# F,-0.32074207067489624
# H,-0.32076573371887207
# N,-0.31868311762809753
# O,-0.32064932584762573
# 1JHC,-0.3068941831588745
# 1JHN,-0.30763354897499084
# 2JHC,-0.3205183446407318
# 2JHH,-0.3212326765060425
# 2JHN,-0.3208469748497009
# 3JHC,-0.3196636140346527
# 3JHH,-0.3199084997177124
# 3JHN,-0.29547062516212463
# neighbour_count_molecule_atom_0,-0.2868534326553345
# neighbour_mean_dist_molecule_atom_0,-0.31678932905197144
# neighbour_std_dist_molecule_atom_0,-0.32053354382514954
# neighbour_min_dist_molecule_atom_0,-0.3203105032444
# neighbour_max_dist_molecule_atom_0,-0.32050684094429016
# neighbour_median_dist_molecule_atom_0,-0.31965771317481995
# neighbour_skew_dist_molecule_atom_0,-0.3174012005329132
# neighbour_mean_dist_x_molecule_atom_0,-0.2889554798603058
# neighbour_std_dist_x_molecule_atom_0,-0.32067808508872986
# neighbour_min_dist_x_molecule_atom_0,-0.32041651010513306
# neighbour_max_dist_x_molecule_atom_0,-0.32031410932540894
# neighbour_median_dist_x_molecule_atom_0,-0.2620476186275482
# neighbour_skew_dist_x_molecule_atom_0,-0.32010361552238464
# neighbour_mean_dist_y_molecule_atom_0,-0.3205757439136505
# neighbour_std_dist_y_molecule_atom_0,-0.3199465870857239
# neighbour_min_dist_y_molecule_atom_0,-0.32098329067230225
# neighbour_max_dist_y_molecule_atom_0,-0.3204590678215027
# neighbour_median_dist_y_molecule_atom_0,-0.29002243280410767
# neighbour_skew_dist_y_molecule_atom_0,-0.2670676112174988
# neighbour_mean_dist_z_molecule_atom_0,-0.2884800434112549
# neighbour_std_dist_z_molecule_atom_0,-0.32062971591949463
# neighbour_min_dist_z_molecule_atom_0,-0.320436954498291
# neighbour_max_dist_z_molecule_atom_0,-0.32000306248664856
# neighbour_median_dist_z_molecule_atom_0,-0.25680020451545715
# neighbour_skew_dist_z_molecule_atom_0,-0.28317326307296753
# neighbour_1JHC_0,-0.31964385509490967
# neighbour_1JHN_0,-0.27123722434043884
# neighbour_2JHC_0,-0.3182201385498047
# neighbour_2JHH_0,-0.29159796237945557
# neighbour_2JHN_0,-0.3197380304336548
# neighbour_3JHC_0,-0.3191218674182892
# neighbour_3JHH_0,-0.2882651090621948
# neighbour_3JHN_0,-0.32002317905426025
# neighbour_C_0,-0.28889772295951843
# neighbour_H_0,-0.31969866156578064
# neighbour_N_0,-0.31964531540870667
# neighbour_count_molecule_atom_1,-0.2988679111003876
# neighbour_mean_dist_molecule_atom_1,-0.3204733431339264
# neighbour_std_dist_molecule_atom_1,-0.2890843152999878
# neighbour_min_dist_molecule_atom_1,-0.32009196281433105
# neighbour_max_dist_molecule_atom_1,-0.2919709384441376
# neighbour_median_dist_molecule_atom_1,-0.3211098313331604
# neighbour_skew_dist_molecule_atom_1,-0.29297471046447754
# neighbour_mean_dist_x_molecule_atom_1,-0.2901391386985779
# neighbour_std_dist_x_molecule_atom_1,-0.26479607820510864
# neighbour_min_dist_x_molecule_atom_1,-0.2563575506210327
# neighbour_max_dist_x_molecule_atom_1,-0.289842426776886
# neighbour_median_dist_x_molecule_atom_1,-0.3204011619091034
# neighbour_skew_dist_x_molecule_atom_1,-0.29037442803382874
# neighbour_mean_dist_y_molecule_atom_1,-0.32043933868408203
# neighbour_std_dist_y_molecule_atom_1,-0.3203255236148834
# neighbour_min_dist_y_molecule_atom_1,-0.27052950859069824
# neighbour_max_dist_y_molecule_atom_1,-0.32062315940856934
# neighbour_median_dist_y_molecule_atom_1,-0.32058364152908325
# neighbour_skew_dist_y_molecule_atom_1,-0.29332417249679565
# neighbour_mean_dist_z_molecule_atom_1,-0.28918740153312683
# neighbour_std_dist_z_molecule_atom_1,-0.28635838627815247
# neighbour_min_dist_z_molecule_atom_1,-0.2601062059402466
# neighbour_max_dist_z_molecule_atom_1,-0.22792983055114746
# neighbour_median_dist_z_molecule_atom_1,-0.28938591480255127
# neighbour_skew_dist_z_molecule_atom_1,-0.2935909628868103
# neighbour_1JHC_1,-0.31949400901794434
# neighbour_1JHN_1,-0.31997400522232056
# neighbour_2JHC_1,-0.3196036219596863
# neighbour_2JHH_1,-0.3196036219596863
# neighbour_2JHN_1,-0.3191481828689575
# neighbour_3JHC_1,-0.3195570409297943
# neighbour_3JHH_1,-0.3195570409297943
# neighbour_3JHN_1,-0.28729724884033203
# neighbour_C_1,-0.3195805847644806
# neighbour_H_1,-0.319580078125
# neighbour_N_1,-0.31958073377609253
# dist_0_n,-0.2931123971939087
# dist_1_n,-0.32027602195739746
# dist_0_f,-0.32047849893569946
# dist_1_f,-0.2928132712841034
# dist_0_c,-0.29241713881492615
# dist_1_c,-0.3161924481391907
# cos_a0n0_a1n1,-0.3190712630748749
# cos_a0f0_a1f1,-0.2858639657497406
# cos_a0c_a1c,-0.32091936469078064
# cos_a0n0_a0a1,-0.30279484391212463
# cos_a1n1_a0a1,-0.3186100125312805
# cos_a0f0_a0a1,-0.2872907519340515
# cos_a1f1_a0a1,-0.2765795886516571
# cos_a0_n_a1_molecule_atom_mean_0,-0.3187427222728729
# cos_a0_n_a1_molecule_atom_std_0,-0.2819615602493286
# cos_a0_n_a1_molecule_atom_min_0,-0.3209155797958374
# cos_a0_n_a1_molecule_atom_max_0,-0.31947916746139526
# cos_a0_n_a1_molecule_atom_median_0,-0.319870263338089
# cos_a0_n_a1_molecule_atom_skew_0,-0.3205089867115021
# cos_a0_f_a1_molecule_atom_mean_0,-0.320993572473526
# cos_a0_f_a1_molecule_atom_std_0,-0.31878000497817993
# cos_a0_f_a1_molecule_atom_min_0,-0.3192082345485687
# cos_a0_f_a1_molecule_atom_max_0,-0.3195292055606842
# cos_a0_f_a1_molecule_atom_median_0,-0.32072317600250244
# cos_a0_f_a1_molecule_atom_skew_0,-0.31868860125541687
# cos_a0_n_a1_molecule_atom_mean_1,-0.3196107745170593
# cos_a0_n_a1_molecule_atom_std_1,-0.2935975193977356
# cos_a0_n_a1_molecule_atom_min_1,-0.2870831787586212
# cos_a0_n_a1_molecule_atom_max_1,-0.28695040941238403
# cos_a0_n_a1_molecule_atom_median_1,-0.2594691514968872
# cos_a0_n_a1_molecule_atom_skew_1,-0.3202109932899475
# cos_a0_f_a1_molecule_atom_mean_1,-0.32051563262939453
# cos_a0_f_a1_molecule_atom_std_1,-0.32011979818344116
# cos_a0_f_a1_molecule_atom_min_1,-0.29019761085510254
# cos_a0_f_a1_molecule_atom_max_1,-0.3195112347602844
# cos_a0_f_a1_molecule_atom_median_1,-0.3209826350212097
# cos_a0_f_a1_molecule_atom_skew_1,-0.2822445034980774
# dist_n_molecule_mean,-0.31987428665161133
# dist_n_molecule_std,-0.3189226984977722
# dist_n_molecule_min,-0.31951937079429626
# dist_n_molecule_max,-0.32021763920783997
# dist_n_molecule_median,-0.32041028141975403
# dist_n_molecule_skew,-0.31966450810432434
# dist_f_molecule_mean,-0.3205828070640564
# dist_f_molecule_std,-0.3204883635044098
# dist_f_molecule_min,-0.32052186131477356
# dist_f_molecule_max,-0.32027101516723633
# dist_f_molecule_median,-0.32060229778289795
# dist_f_molecule_skew,-0.28500187397003174
# dist_n_molecule_type_mean_0,-0.32066553831100464
# dist_n_molecule_type_std_0,-0.25922656059265137
# dist_n_molecule_type_min_0,-0.3195846676826477
# dist_n_molecule_type_max_0,-0.28609055280685425
# dist_n_molecule_type_median_0,-0.29161152243614197
# dist_n_molecule_type_skew_0,-0.32019349932670593
# dist_f_molecule_type_mean_0,-0.3206081986427307
# dist_f_molecule_type_std_0,-0.2919981777667999
# dist_f_molecule_type_min_0,-0.32079949975013733
# dist_f_molecule_type_max_0,-0.28818026185035706
# dist_f_molecule_type_median_0,-0.2924294173717499
# dist_f_molecule_type_skew_0,-0.29059088230133057
# dist_n_molecule_type_mean_1,-0.2959994673728943
# dist_n_molecule_type_std_1,-0.31993138790130615
# dist_n_molecule_type_min_1,-0.2892538607120514
# dist_n_molecule_type_max_1,-0.3207363486289978
# dist_n_molecule_type_median_1,-0.2902778387069702
# dist_n_molecule_type_skew_1,-0.28741198778152466
# dist_f_molecule_type_mean_1,-0.26201385259628296
# dist_f_molecule_type_std_1,-0.2905118763446808
# dist_f_molecule_type_min_1,-0.25304508209228516
# dist_f_molecule_type_max_1,-0.3209330141544342
# dist_f_molecule_type_median_1,-0.2892814576625824
# dist_f_molecule_type_skew_1,-0.2855992019176483
# atom_2,-0.319996178150177
# atom_3,-0.2688307762145996
# atom_4,-0.235021710395813
# atom_5,-0.30601897835731506
# atom_6,-0.32036617398262024
# atom_7,-0.31991687417030334
# atom_8,-0.3206804096698761
# atom_9,-0.3190730810165405
# d_1_0,-0.32031452655792236
# d_2_0,-0.29738348722457886
# d_2_1,-0.2994747757911682
# d_3_0,-0.2866126298904419
# d_3_1,-0.30485931038856506
# d_3_2,-0.2775465250015259
# d_4_0,-0.2926770746707916
# d_4_1,-0.24271143972873688
# d_4_2,-0.2923457622528076
# d_4_3,-0.29956090450286865
# d_5_0,-0.2810387909412384
# d_5_1,-0.2645113468170166
# d_5_2,-0.30170249938964844
# d_5_3,-0.2638311982154846
# d_6_0,-0.29806816577911377
# d_6_1,-0.32034942507743835
# d_6_2,-0.28814032673835754
# d_6_3,-0.303561806678772
# d_7_0,-0.31763333082199097
# d_7_1,-0.3193019926548004
# d_7_2,-0.29637008905410767
# d_7_3,-0.3154120147228241
# d_8_0,-0.3202877640724182
# d_8_1,-0.32054832577705383
# d_8_2,-0.3207184970378876
# d_8_3,-0.31960758566856384
# d_9_0,-0.3197292685508728
# d_9_1,-0.32006019353866577
# d_9_2,-0.28852379322052
# d_9_3,-0.284416139125824
# rc_A,-0.3199206590652466
# rc_B,-0.3200746476650238
# rc_C,-0.32038334012031555
# mu,-0.2839093804359436
# alpha,-0.3192756474018097
# homo,-0.3211802542209625
# lumo,-0.2904568910598755
# gap,-0.32076409459114075
# zpve,-0.2840515971183777
# Cv,-0.31957459449768066
# freqs_min,-0.3194296360015869
# freqs_max,-0.32112815976142883
# freqs_mean,-0.31935915350914
# mulliken_min,-0.28676584362983704
# mulliken_max,-0.2651793360710144
# mulliken_atom_0,-0.3076384961605072
# mulliken_atom_1,-0.3156324028968811
# random_feature,-0.28968504071235657
# For bond type 2JHC:
# dist_x,0.565724790096283
# dist_y,0.562374472618103
# dist_z,0.6019843816757202
# dist,0.5733634233474731
# dist_x_molecule_mean,0.5563554763793945
# dist_x_molecule_std,0.5783173441886902
# dist_x_molecule_min,0.554046094417572
# dist_x_molecule_max,0.5556292533874512
# dist_x_molecule_median,0.5483742952346802
# dist_x_molecule_skew,0.5675203204154968
# dist_y_molecule_mean,0.544940173625946
# dist_y_molecule_std,0.5651838779449463
# dist_y_molecule_min,0.5506266355514526
# dist_y_molecule_max,0.5720453858375549
# dist_y_molecule_median,0.5557469129562378
# dist_y_molecule_skew,0.5604533553123474
# dist_z_molecule_mean,0.5434349775314331
# dist_z_molecule_std,0.5743234157562256
# dist_z_molecule_min,0.5828339457511902
# dist_z_molecule_max,0.5562289953231812
# dist_z_molecule_median,0.5714019536972046
# dist_z_molecule_skew,0.5598698854446411
# dist_molecule_mean,0.5572187304496765
# dist_molecule_std,0.5600322484970093
# dist_molecule_min,0.5355896353721619
# dist_molecule_max,0.5616734623908997
# dist_molecule_median,0.546571671962738
# dist_molecule_skew,0.5700551271438599
# dist_x_molecule_type_mean,0.5698527097702026
# dist_x_molecule_type_std,0.5590288639068604
# dist_x_molecule_type_min,0.5621480941772461
# dist_x_molecule_type_max,0.5457320213317871
# dist_x_molecule_type_median,0.5664432644844055
# dist_x_molecule_type_skew,0.5381274223327637
# dist_y_molecule_type_mean,0.5560944080352783
# dist_y_molecule_type_std,0.550130307674408
# dist_y_molecule_type_min,0.5587317943572998
# dist_y_molecule_type_max,0.5552651882171631
# dist_y_molecule_type_median,0.5349233150482178
# dist_y_molecule_type_skew,0.5519640445709229
# dist_z_molecule_type_mean,0.553865373134613
# dist_z_molecule_type_std,0.5470614433288574
# dist_z_molecule_type_min,0.5647858381271362
# dist_z_molecule_type_max,0.5660454034805298
# dist_z_molecule_type_median,0.5631917119026184
# dist_z_molecule_type_skew,0.5524663925170898
# dist_molecule_type_mean,0.5616514682769775
# dist_molecule_type_std,0.5596009492874146
# dist_molecule_type_min,0.5688683390617371
# dist_molecule_type_max,0.5458906292915344
# dist_molecule_type_median,0.5753906965255737
# dist_molecule_type_skew,0.5539010167121887
# C,0.5503339767456055
# F,0.5541515350341797
# H,0.5587218999862671
# N,0.5647240877151489
# O,0.5491567850112915
# 1JHC,0.5655142664909363
# 1JHN,0.5506401658058167
# 2JHC,0.5835862159729004
# 2JHH,0.5511060357093811
# 2JHN,0.5681045651435852
# 3JHC,0.5556768774986267
# 3JHH,0.5503706932067871
# 3JHN,0.5490188598632812
# neighbour_count_molecule_atom_0,0.5512620806694031
# neighbour_mean_dist_molecule_atom_0,0.5618461966514587
# neighbour_std_dist_molecule_atom_0,0.5609968304634094
# neighbour_min_dist_molecule_atom_0,0.5414343476295471
# neighbour_max_dist_molecule_atom_0,0.572199821472168
# neighbour_median_dist_molecule_atom_0,0.5500604510307312
# neighbour_skew_dist_molecule_atom_0,0.570697009563446
# neighbour_mean_dist_x_molecule_atom_0,0.5612393617630005
# neighbour_std_dist_x_molecule_atom_0,0.5772234201431274
# neighbour_min_dist_x_molecule_atom_0,0.5601023435592651
# neighbour_max_dist_x_molecule_atom_0,0.5547182559967041
# neighbour_median_dist_x_molecule_atom_0,0.5554099082946777
# neighbour_skew_dist_x_molecule_atom_0,0.5613083839416504
# neighbour_mean_dist_y_molecule_atom_0,0.5581928491592407
# neighbour_std_dist_y_molecule_atom_0,0.569328248500824
# neighbour_min_dist_y_molecule_atom_0,0.5394155383110046
# neighbour_max_dist_y_molecule_atom_0,0.5622258186340332
# neighbour_median_dist_y_molecule_atom_0,0.5530144572257996
# neighbour_skew_dist_y_molecule_atom_0,0.5604974627494812
# neighbour_mean_dist_z_molecule_atom_0,0.566321611404419
# neighbour_std_dist_z_molecule_atom_0,0.5641833543777466
# neighbour_min_dist_z_molecule_atom_0,0.5562353134155273
# neighbour_max_dist_z_molecule_atom_0,0.548593282699585
# neighbour_median_dist_z_molecule_atom_0,0.5609225034713745
# neighbour_skew_dist_z_molecule_atom_0,0.5445700883865356
# neighbour_1JHC_0,0.5672541856765747
# neighbour_1JHN_0,0.5508381128311157
# neighbour_2JHC_0,0.5458894968032837
# neighbour_2JHH_0,0.5459091067314148
# neighbour_2JHN_0,0.5611603260040283
# neighbour_3JHC_0,0.5648159980773926
# neighbour_3JHH_0,0.5507630109786987
# neighbour_3JHN_0,0.566771388053894
# neighbour_C_0,0.5519619584083557
# neighbour_H_0,0.540444016456604
# ...
# neighbour_2JHN_1,0.5800530314445496
# neighbour_3JHC_1,0.580119788646698
# neighbour_3JHH_1,0.5801091194152832
# neighbour_3JHN_1,0.5801091194152832
# neighbour_C_1,0.5801091194152832
# neighbour_H_1,0.5801091194152832
# neighbour_N_1,0.5801091194152832
# dist_0_n,0.5800238251686096
# dist_1_n,0.5799866318702698
# dist_0_f,0.5797356367111206
# dist_1_f,0.5801912546157837
# dist_0_c,0.5812749862670898
# dist_1_c,0.580110490322113
# cos_a0n0_a1n1,0.5816817879676819
# cos_a0f0_a1f1,0.5799063444137573
# cos_a0c_a1c,0.5796799659729004
# cos_a0n0_a0a1,0.5838736295700073
# cos_a1n1_a0a1,0.580532431602478
# cos_a0f0_a0a1,0.5814239978790283
# cos_a1f1_a0a1,0.5799403786659241
# cos_a0_n_a1_molecule_atom_mean_0,0.5834518074989319
# cos_a0_n_a1_molecule_atom_std_0,0.5824737548828125
# cos_a0_n_a1_molecule_atom_min_0,0.5815369486808777
# cos_a0_n_a1_molecule_atom_max_0,0.5800976753234863
# cos_a0_n_a1_molecule_atom_median_0,0.5811525583267212
# cos_a0_n_a1_molecule_atom_skew_0,0.5825135111808777
# cos_a0_f_a1_molecule_atom_mean_0,0.5801774263381958
# cos_a0_f_a1_molecule_atom_std_0,0.5799734592437744
# cos_a0_f_a1_molecule_atom_min_0,0.5799517631530762
# cos_a0_f_a1_molecule_atom_max_0,0.5801049470901489
# cos_a0_f_a1_molecule_atom_median_0,0.5797587633132935
# cos_a0_f_a1_molecule_atom_skew_0,0.5794670581817627
# cos_a0_n_a1_molecule_atom_mean_1,0.579952597618103
# cos_a0_n_a1_molecule_atom_std_1,0.5801939964294434
# cos_a0_n_a1_molecule_atom_min_1,0.5803439021110535
# cos_a0_n_a1_molecule_atom_max_1,0.580097496509552
# cos_a0_n_a1_molecule_atom_median_1,0.5799816250801086
# cos_a0_n_a1_molecule_atom_skew_1,0.5795922875404358
# cos_a0_f_a1_molecule_atom_mean_1,0.5799062252044678
# cos_a0_f_a1_molecule_atom_std_1,0.580737829208374
# cos_a0_f_a1_molecule_atom_min_1,0.5806620717048645
# cos_a0_f_a1_molecule_atom_max_1,0.5800963044166565
# cos_a0_f_a1_molecule_atom_median_1,0.5799150466918945
# cos_a0_f_a1_molecule_atom_skew_1,0.5798107385635376
# dist_n_molecule_mean,0.5795927047729492
# dist_n_molecule_std,0.5801282525062561
# dist_n_molecule_min,0.5798321962356567
# dist_n_molecule_max,0.5799318552017212
# dist_n_molecule_median,0.5803552269935608
# dist_n_molecule_skew,0.5800198912620544
# dist_f_molecule_mean,0.5800557136535645
# dist_f_molecule_std,0.5801386833190918
# dist_f_molecule_min,0.5804936289787292
# dist_f_molecule_max,0.5798116326332092
# dist_f_molecule_median,0.5798025727272034
# dist_f_molecule_skew,0.5794623494148254
# dist_n_molecule_type_mean_0,0.5800984501838684
# dist_n_molecule_type_std_0,0.5797101259231567
# dist_n_molecule_type_min_0,0.5798318982124329
# dist_n_molecule_type_max_0,0.579613447189331
# dist_n_molecule_type_median_0,0.580578088760376
# dist_n_molecule_type_skew_0,0.5799013376235962
# dist_f_molecule_type_mean_0,0.5807982683181763
# dist_f_molecule_type_std_0,0.5797721743583679
# dist_f_molecule_type_min_0,0.5802927017211914
# dist_f_molecule_type_max_0,0.5798050761222839
# dist_f_molecule_type_median_0,0.579747200012207
# dist_f_molecule_type_skew_0,0.5796513557434082
# dist_n_molecule_type_mean_1,0.58024662733078
# dist_n_molecule_type_std_1,0.5800355672836304
# dist_n_molecule_type_min_1,0.5801516175270081
# dist_n_molecule_type_max_1,0.5796818137168884
# dist_n_molecule_type_median_1,0.5798095464706421
# dist_n_molecule_type_skew_1,0.5796120762825012
# dist_f_molecule_type_mean_1,0.5799424648284912
# dist_f_molecule_type_std_1,0.5798264145851135
# dist_f_molecule_type_min_1,0.5798132419586182
# dist_f_molecule_type_max_1,0.5797844529151917
# dist_f_molecule_type_median_1,0.5802820920944214
# dist_f_molecule_type_skew_1,0.5798501372337341
# atom_2,0.5801888108253479
# atom_3,0.5820159912109375
# atom_4,0.5845019221305847
# atom_5,0.5813266634941101
# atom_6,0.5811700820922852
# atom_7,0.5796552896499634
# atom_8,0.5811318755149841
# atom_9,0.581213116645813
# d_1_0,0.5793377757072449
# d_2_0,0.6201657056808472
# d_2_1,0.623640775680542
# d_3_0,0.5915808081626892
# d_3_1,0.5917096138000488
# d_3_2,0.5805969834327698
# d_4_0,0.5841837525367737
# d_4_1,0.5856744647026062
# d_4_2,0.5805000066757202
# d_4_3,0.5806127786636353
# d_5_0,0.5805640816688538
# d_5_1,0.581368088722229
# d_5_2,0.5796579718589783
# d_5_3,0.5805183053016663
# d_6_0,0.5801899433135986
# d_6_1,0.5802430510520935
# d_6_2,0.579350471496582
# d_6_3,0.5799264907836914
# d_7_0,0.5800231695175171
# d_7_1,0.580016553401947
# d_7_2,0.5793707966804504
# d_7_3,0.5797160267829895
# d_8_0,0.5801578760147095
# d_8_1,0.5798535346984863
# d_8_2,0.5795178413391113
# d_8_3,0.5801287889480591
# d_9_0,0.5798875093460083
# d_9_1,0.5800904035568237
# d_9_2,0.5797363519668579
# d_9_3,0.5796794295310974
# rc_A,0.577540397644043
# rc_B,0.5798641443252563
# rc_C,0.5799211263656616
# mu,0.5794884562492371
# alpha,0.5802019238471985
# homo,0.5800905227661133
# lumo,0.5802149772644043
# gap,0.5802039504051208
# zpve,0.58050537109375
# Cv,0.5816622376441956
# freqs_min,0.5794081687927246
# freqs_max,0.5804643034934998
# freqs_mean,0.5812665820121765
# mulliken_min,0.5803658366203308
# mulliken_max,0.5804746747016907
# mulliken_atom_0,0.5817087888717651
# mulliken_atom_1,0.5814589262008667
# random_feature,0.5795982480049133
# For bond type 3JHN:
# dist_x,-0.3651827573776245
# dist_y,-0.3646996319293976
# dist_z,-0.36515671014785767
# dist,-0.36516231298446655
# dist_x_molecule_mean,-0.36513370275497437
# dist_x_molecule_std,-0.3652687072753906
# dist_x_molecule_min,-0.36519956588745117
# dist_x_molecule_max,-0.36497819423675537
# dist_x_molecule_median,-0.36516496539115906
# dist_x_molecule_skew,-0.3649246394634247
# dist_y_molecule_mean,-0.3649705648422241
# dist_y_molecule_std,-0.36511507630348206
# dist_y_molecule_min,-0.36519140005111694
# dist_y_molecule_max,-0.3652432858943939
# dist_y_molecule_median,-0.3652189075946808
# dist_y_molecule_skew,-0.3652456998825073
# dist_z_molecule_mean,-0.3649502992630005
# dist_z_molecule_std,-0.3650924861431122
# dist_z_molecule_min,-0.36520206928253174
# dist_z_molecule_max,-0.36513352394104004
# dist_z_molecule_median,-0.36518633365631104
# dist_z_molecule_skew,-0.3651503622531891
# dist_molecule_mean,-0.3648902177810669
# dist_molecule_std,-0.3648090660572052
# dist_molecule_min,-0.365206778049469
# dist_molecule_max,-0.36517277359962463
# dist_molecule_median,-0.3652556538581848
# dist_molecule_skew,-0.36524054408073425
# dist_x_molecule_type_mean,-0.36515724658966064
# dist_x_molecule_type_std,-0.3651588559150696
# dist_x_molecule_type_min,-0.36517003178596497
# dist_x_molecule_type_max,-0.36518728733062744
# dist_x_molecule_type_median,-0.36518076062202454
# dist_x_molecule_type_skew,-0.3652910590171814
# dist_y_molecule_type_mean,-0.36521977186203003
# dist_y_molecule_type_std,-0.3651997447013855
# dist_y_molecule_type_min,-0.3651849031448364
# dist_y_molecule_type_max,-0.3652575612068176
# dist_y_molecule_type_median,-0.3652001917362213
# dist_y_molecule_type_skew,-0.3652658760547638
# dist_z_molecule_type_mean,-0.36522114276885986
# dist_z_molecule_type_std,-0.36513859033584595
# dist_z_molecule_type_min,-0.36518627405166626
# dist_z_molecule_type_max,-0.3651467561721802
# dist_z_molecule_type_median,-0.36516958475112915
# dist_z_molecule_type_skew,-0.3651992380619049
# dist_molecule_type_mean,-0.365217000246048
# dist_molecule_type_std,-0.364188015460968
# dist_molecule_type_min,-0.3651787042617798
# dist_molecule_type_max,-0.36515775322914124
# dist_molecule_type_median,-0.36529070138931274
# dist_molecule_type_skew,-0.3651409149169922
# C,-0.3650280833244324
# F,-0.3650747239589691
# H,-0.3648795485496521
# N,-0.36548858880996704
# O,-0.3651636838912964
# 1JHC,-0.3655127286911011
# 1JHN,-0.36501041054725647
# 2JHC,-0.36498644948005676
# 2JHH,-0.36522603034973145
# 2JHN,-0.36502501368522644
# 3JHC,-0.36513611674308777
# 3JHH,-0.36517783999443054
# 3JHN,-0.36509954929351807
# neighbour_count_molecule_atom_0,-0.3652106523513794
# neighbour_mean_dist_molecule_atom_0,-0.36000797152519226
# neighbour_std_dist_molecule_atom_0,-0.3609504997730255
# neighbour_min_dist_molecule_atom_0,-0.3651075065135956
# neighbour_max_dist_molecule_atom_0,-0.36518436670303345
# neighbour_median_dist_molecule_atom_0,-0.356464147567749
# neighbour_skew_dist_molecule_atom_0,-0.36519861221313477
# neighbour_mean_dist_x_molecule_atom_0,-0.36514538526535034
# neighbour_std_dist_x_molecule_atom_0,-0.3651812672615051
# neighbour_min_dist_x_molecule_atom_0,-0.36515432596206665
# neighbour_max_dist_x_molecule_atom_0,-0.36500775814056396
# neighbour_median_dist_x_molecule_atom_0,-0.3649468719959259
# neighbour_skew_dist_x_molecule_atom_0,-0.36521393060684204
# neighbour_mean_dist_y_molecule_atom_0,-0.365203857421875
# neighbour_std_dist_y_molecule_atom_0,-0.36509573459625244
# neighbour_min_dist_y_molecule_atom_0,-0.3651792109012604
# neighbour_max_dist_y_molecule_atom_0,-0.36528974771499634
# neighbour_median_dist_y_molecule_atom_0,-0.3652183711528778
# neighbour_skew_dist_y_molecule_atom_0,-0.3652460277080536
# neighbour_mean_dist_z_molecule_atom_0,-0.3650989234447479
# neighbour_std_dist_z_molecule_atom_0,-0.3650623559951782
# neighbour_min_dist_z_molecule_atom_0,-0.36508071422576904
# neighbour_max_dist_z_molecule_atom_0,-0.36503341794013977
# neighbour_median_dist_z_molecule_atom_0,-0.36486995220184326
# neighbour_skew_dist_z_molecule_atom_0,-0.3649945855140686
# neighbour_1JHC_0,-0.3644816279411316
# neighbour_1JHN_0,-0.364742636680603
# neighbour_2JHC_0,-0.3652741312980652
# neighbour_2JHH_0,-0.36523711681365967
# neighbour_2JHN_0,-0.3653388023376465
# neighbour_3JHC_0,-0.3651888370513916
# neighbour_3JHH_0,-0.36528244614601135
# neighbour_3JHN_0,-0.3651854991912842
# neighbour_C_0,-0.3652336001396179
# neighbour_H_0,-0.3652031123638153
# neighbour_N_0,-0.3651796579360962
# neighbour_count_molecule_atom_1,-0.36292415857315063
# neighbour_mean_dist_molecule_atom_1,-0.3650507628917694
# neighbour_std_dist_molecule_atom_1,-0.36220306158065796
# neighbour_min_dist_molecule_atom_1,-0.3651982843875885
# neighbour_max_dist_molecule_atom_1,-0.36516737937927246
# neighbour_median_dist_molecule_atom_1,-0.3639112710952759
# neighbour_skew_dist_molecule_atom_1,-0.36524003744125366
# neighbour_mean_dist_x_molecule_atom_1,-0.3651900291442871
# neighbour_std_dist_x_molecule_atom_1,-0.3652339279651642
# neighbour_min_dist_x_molecule_atom_1,-0.3651966452598572
# neighbour_max_dist_x_molecule_atom_1,-0.36517131328582764
# neighbour_median_dist_x_molecule_atom_1,-0.3651707172393799
# neighbour_skew_dist_x_molecule_atom_1,-0.3652031123638153
# neighbour_mean_dist_y_molecule_atom_1,-0.3651866912841797
# neighbour_std_dist_y_molecule_atom_1,-0.36519888043403625
# neighbour_min_dist_y_molecule_atom_1,-0.3651461601257324
# neighbour_max_dist_y_molecule_atom_1,-0.3649841248989105
# neighbour_median_dist_y_molecule_atom_1,-0.3651864230632782
# neighbour_skew_dist_y_molecule_atom_1,-0.3652193248271942
# neighbour_mean_dist_z_molecule_atom_1,-0.3652254343032837
# neighbour_std_dist_z_molecule_atom_1,-0.36510151624679565
# neighbour_min_dist_z_molecule_atom_1,-0.3651646375656128
# neighbour_max_dist_z_molecule_atom_1,-0.36520034074783325
# neighbour_median_dist_z_molecule_atom_1,-0.36522164940834045
# neighbour_skew_dist_z_molecule_atom_1,-0.3651762008666992
# neighbour_1JHC_1,-0.3651828169822693
# neighbour_1JHN_1,-0.3651565611362457
# neighbour_2JHC_1,-0.3651828169822693
# neighbour_2JHH_1,-0.3651828169822693
# neighbour_2JHN_1,-0.36526012420654297
# neighbour_3JHC_1,-0.3651787042617798
# neighbour_3JHH_1,-0.3651787042617798
# neighbour_3JHN_1,-0.36514419317245483
# neighbour_C_1,-0.3651820421218872
# neighbour_H_1,-0.3651820421218872
# neighbour_N_1,-0.36518213152885437
# dist_0_n,-0.3651091456413269
# dist_1_n,-0.3651978671550751
# dist_0_f,-0.36518532037734985
# dist_1_f,-0.36516693234443665
# dist_0_c,-0.3646996319293976
# dist_1_c,-0.3625100553035736
# cos_a0n0_a1n1,-0.36487269401550293
# cos_a0f0_a1f1,-0.36495932936668396
# cos_a0c_a1c,-0.3636888265609741
# cos_a0n0_a0a1,-0.36325323581695557
# cos_a1n1_a0a1,-0.35351598262786865
# cos_a0f0_a0a1,-0.3647586703300476
# cos_a1f1_a0a1,-0.3651666045188904
# cos_a0_n_a1_molecule_atom_mean_0,-0.36444157361984253
# cos_a0_n_a1_molecule_atom_std_0,-0.3641902506351471
# cos_a0_n_a1_molecule_atom_min_0,-0.36419743299484253
# cos_a0_n_a1_molecule_atom_max_0,-0.3651825785636902
# cos_a0_n_a1_molecule_atom_median_0,-0.3655088543891907
# cos_a0_n_a1_molecule_atom_skew_0,-0.3642461895942688
# cos_a0_f_a1_molecule_atom_mean_0,-0.3649424910545349
# cos_a0_f_a1_molecule_atom_std_0,-0.36119791865348816
# cos_a0_f_a1_molecule_atom_min_0,-0.3646569848060608
# cos_a0_f_a1_molecule_atom_max_0,-0.3651849627494812
# cos_a0_f_a1_molecule_atom_median_0,-0.365252822637558
# cos_a0_f_a1_molecule_atom_skew_0,-0.3646363615989685
# cos_a0_n_a1_molecule_atom_mean_1,-0.3650279939174652
# cos_a0_n_a1_molecule_atom_std_1,-0.36524879932403564
# cos_a0_n_a1_molecule_atom_min_1,-0.36509084701538086
# cos_a0_n_a1_molecule_atom_max_1,-0.3651827573776245
# cos_a0_n_a1_molecule_atom_median_1,-0.3641585111618042
# cos_a0_n_a1_molecule_atom_skew_1,-0.3652408719062805
# cos_a0_f_a1_molecule_atom_mean_1,-0.36489278078079224
# cos_a0_f_a1_molecule_atom_std_1,-0.3651208281517029
# cos_a0_f_a1_molecule_atom_min_1,-0.36333441734313965
# cos_a0_f_a1_molecule_atom_max_1,-0.365189790725708
# cos_a0_f_a1_molecule_atom_median_1,-0.3651752769947052
# cos_a0_f_a1_molecule_atom_skew_1,-0.36387449502944946
# dist_n_molecule_mean,-0.365031361579895
# dist_n_molecule_std,-0.36521339416503906
# dist_n_molecule_min,-0.36520645022392273
# dist_n_molecule_max,-0.3642750084400177
# dist_n_molecule_median,-0.36513593792915344
# dist_n_molecule_skew,-0.364769846200943
# dist_f_molecule_mean,-0.36522895097732544
# dist_f_molecule_std,-0.3652075529098511
# dist_f_molecule_min,-0.36511096358299255
# dist_f_molecule_max,-0.3651764690876007
# dist_f_molecule_median,-0.3651951849460602
# dist_f_molecule_skew,-0.36520516872406006
# dist_n_molecule_type_mean_0,-0.3653411865234375
# dist_n_molecule_type_std_0,-0.3652569353580475
# dist_n_molecule_type_min_0,-0.365208238363266
# dist_n_molecule_type_max_0,-0.36520901322364807
# dist_n_molecule_type_median_0,-0.3652218282222748
# dist_n_molecule_type_skew_0,-0.3651939928531647
# dist_f_molecule_type_mean_0,-0.3651750981807709
# dist_f_molecule_type_std_0,-0.36524373292922974
# dist_f_molecule_type_min_0,-0.36523932218551636
# dist_f_molecule_type_max_0,-0.3651815354824066
# dist_f_molecule_type_median_0,-0.3650931715965271
# dist_f_molecule_type_skew_0,-0.36517560482025146
# dist_n_molecule_type_mean_1,-0.36531001329421997
# dist_n_molecule_type_std_1,-0.3652164936065674
# dist_n_molecule_type_min_1,-0.3653436005115509
# dist_n_molecule_type_max_1,-0.3652384877204895
# dist_n_molecule_type_median_1,-0.36532866954803467
# dist_n_molecule_type_skew_1,-0.3654056191444397
# dist_f_molecule_type_mean_1,-0.365388959646225
# dist_f_molecule_type_std_1,-0.3654826879501343
# dist_f_molecule_type_min_1,-0.36542847752571106
# dist_f_molecule_type_max_1,-0.365159809589386
# dist_f_molecule_type_median_1,-0.36538320779800415
# dist_f_molecule_type_skew_1,-0.3651886582374573
# atom_2,-0.3607928156852722
# atom_3,-0.360813170671463
# atom_4,-0.3621578514575958
# atom_5,-0.3584114909172058
# atom_6,-0.36321166157722473
# atom_7,-0.36536645889282227
# atom_8,-0.3638845384120941
# atom_9,-0.36515113711357117
# d_1_0,-0.3651715815067291
# d_2_0,-0.34244197607040405
# d_2_1,-0.3539915084838867
# d_3_0,-0.34846633672714233
# d_3_1,-0.3549039661884308
# d_3_2,-0.36353355646133423
# d_4_0,-0.3650656044483185
# d_4_1,-0.36513131856918335
# d_4_2,-0.36508801579475403
# d_4_3,-0.36465635895729065
# d_5_0,-0.36504894495010376
# d_5_1,-0.36492711305618286
# d_5_2,-0.36511147022247314
# d_5_3,-0.3639587163925171
# d_6_0,-0.3630569577217102
# d_6_1,-0.36301499605178833
# d_6_2,-0.3651835024356842
# d_6_3,-0.3652673363685608
# d_7_0,-0.3652268648147583
# d_7_1,-0.36511147022247314
# d_7_2,-0.36386677622795105
# d_7_3,-0.364995539188385
# d_8_0,-0.36395296454429626
# d_8_1,-0.3644961416721344
# d_8_2,-0.3648895025253296
# d_8_3,-0.36524295806884766
# d_9_0,-0.36475154757499695
# d_9_1,-0.3649296164512634
# d_9_2,-0.36509591341018677
# d_9_3,-0.3651244342327118
# rc_A,-0.36521339416503906
# rc_B,-0.3644067049026489
# rc_C,-0.36515647172927856
# mu,-0.3651925325393677
# alpha,-0.3643263280391693
# homo,-0.36509969830513
# lumo,-0.3650425970554352
# gap,-0.3651264011859894
# zpve,-0.3653259873390198
# Cv,-0.36452993750572205
# freqs_min,-0.3652370274066925
# freqs_max,-0.36528339982032776
# freqs_mean,-0.3637007474899292
# mulliken_min,-0.3653288185596466
# mulliken_max,-0.3651035726070404
# mulliken_atom_0,-0.34490689635276794
# mulliken_atom_1,-0.3461998403072357
# random_feature,-0.3651791214942932
